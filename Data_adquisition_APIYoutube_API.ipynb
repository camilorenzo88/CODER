# %% [markdown]
# <a href="https://colab.research.google.com/github/camilorenzo88/CODER/blob/main/Data_adquisition_APIYoutube_API.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from googleapiclient.discovery import build
api_key='AIzaSyAgkNuTIeyJKXLn7ZYYn9QWQvAfMVezc-Y'
youtube_videos= build('youtube','v3',developerKey=api_key)

# %% [markdown]
# Canal para analizar www.youtube.com/channel/UCfzlCWGWYyIQ0aLC5w48gBQ

# %%
request = youtube_videos.channels().list(
    part='statistics',
    forUsername= 'sentdex'
)

# %%
response=request.execute()
print(response) # Obtenemos informacion
# Out:
# {'kind': 'youtube#channelListResponse', 'etag': 'po9-x9UQvxtwW5e5ouC9bDTh35Y', 'pageInfo': {'totalResults': 1, 'resultsPerPage': 5}, 'items': [{'kind': 'youtube#channel', 'etag': '_PLD03UvWNTKe-x1iAuvVcMokCg', 'id': 'UCfzlCWGWYyIQ0aLC5w48gBQ', 'statistics': {'viewCount': '114621699', 'subscriberCount': '1330000', 'hiddenSubscriberCount': False, 'videoCount': '1254'}}]}

# %%
response['pageInfo']
# Out:
# {'totalResults': 1, 'resultsPerPage': 5}

# %%
response['items']
# Out:
# [{'kind': 'youtube#channel',
#   'etag': '_PLD03UvWNTKe-x1iAuvVcMokCg',
#   'id': 'UCfzlCWGWYyIQ0aLC5w48gBQ',
#   'statistics': {'viewCount': '114621699',
#    'subscriberCount': '1330000',
#    'hiddenSubscriberCount': False,
#    'videoCount': '1254'}}]

# %%
import pandas as pd
import json

# %%
df1= pd.DataFrame.from_dict(response['items'])
df1
# Out:
#               kind                         etag                        id  \
# 0  youtube#channel  _PLD03UvWNTKe-x1iAuvVcMokCg  UCfzlCWGWYyIQ0aLC5w48gBQ
#
#                                           statistics
# 0  {'viewCount': '114621699', 'subscriberCount': ...

# %%
df2= pd.DataFrame.from_dict([response['items'][0]['statistics']])
df2
# Out:
#    viewCount subscriberCount  hiddenSubscriberCount videoCount
# 0  114621699         1330000                  False       1254

# %%
df3= pd.DataFrame.from_dict(response['items'][0])
df3
# Out:
#                                   kind                         etag  \
# hiddenSubscriberCount  youtube#channel  _PLD03UvWNTKe-x1iAuvVcMokCg
# subscriberCount        youtube#channel  _PLD03UvWNTKe-x1iAuvVcMokCg
# videoCount             youtube#channel  _PLD03UvWNTKe-x1iAuvVcMokCg
# viewCount              youtube#channel  _PLD03UvWNTKe-x1iAuvVcMokCg
#
#                                              id statistics
# hiddenSubscriberCount  UCfzlCWGWYyIQ0aLC5w48gBQ      False
# subscriberCount        UCfzlCWGWYyIQ0aLC5w48gBQ    1330000
# videoCount             UCfzlCWGWYyIQ0aLC5w48gBQ       1254
# viewCount              UCfzlCWGWYyIQ0aLC5w48gBQ  114621699
